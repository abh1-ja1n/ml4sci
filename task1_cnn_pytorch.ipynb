# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import h5py
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %%
file_electron = "SingleElectronPt50_IMGCROPS_n249k_RHv1.hdf5"
file_proton = "SinglePhotonPt50_IMGCROPS_n249k_RHv1.hdf5"


with h5py.File(file_electron, "r") as f1:
    X_elec = np.array(f1['X'][:])
    y_elec = np.array(f1['y'][:])
with h5py.File(file_proton, "r") as f2:
    X_prot = np.array(f2['X'][:])
    y_prot = np.array(f2['y'][:])

# %%
print(X_elec.shape)
print(X_prot.shape)
# Out:
# (249000, 32, 32, 2)
# (249000, 32, 32, 2)

# %%
X = np.append(X_elec, X_prot, axis=0)
y = np.append(y_elec, y_prot)
X.shape
# Out:
# (498000, 32, 32, 2)

# %%
X = np.swapaxes(X, 3,1)
X.shape
# Out:
# (498000, 2, 32, 32)

# %%
y = torch.as_tensor(y)

# %%
X = torch.from_numpy(X)

# %%
dataset = torch.utils.data.TensorDataset(X, y)

# %%
train_data,val_data = torch.utils.data.random_split(dataset,[int(len(dataset)*0.9),int(len(dataset)*0.1)])

# %%
trainset = torch.utils.data.DataLoader(train_data, batch_size=256, shuffle=True, num_workers=4, pin_memory=True)
valset = torch.utils.data.DataLoader(val_data, batch_size=256, shuffle=True, num_workers=4, pin_memory=True)

# %%
class CNN(nn.Module):
    def __init__(self):
        super().__init__()
        self.conv1 = nn.Conv2d(in_channels=2, out_channels=16, kernel_size=2, padding='same')
        self.pool = nn.MaxPool2d(2, 2)
        self.fc1 = nn.Linear(16 * 16 * 16, 64)
        self.out = nn.Linear(64,2)

    def forward(self, x):
        x = self.pool(F.relu(self.conv1(x)))
        x = torch.flatten(x, 1)
        x = F.relu(self.fc1(x))
        x = F.softmax(self.out(x))
        return x

# %%
model = CNN()
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=0.0001)
if torch.cuda.is_available():
    model = model.cuda()
    criterion = criterion.cuda()

# %%
from sklearn.metrics import roc_auc_score
for epoch in range(100):
    running_loss = 0.0
    val_loss = 0.0
    all_y_true = torch.zeros(0, dtype=torch.long, device='cuda')
    all_y_pred = torch.zeros(0, dtype=torch.long, device='cuda')
    all_y_true_val = torch.zeros(0, dtype=torch.long, device='cuda')
    all_y_pred_val = torch.zeros(0, dtype=torch.long, device='cuda')
    
    
    
    for i, data in enumerate(trainset, 0):
        X, y = data
        if torch.cuda.is_available():
            X = X.cuda()
            y = y.cuda()
        optimizer.zero_grad()
        outputs = model(X)
        preds = outputs
        preds = preds.detach()
        _,preds = torch.max(preds, 1)
        all_y_true=torch.cat((all_y_true,y.view(-1)))
        all_y_pred=torch.cat((all_y_pred,preds.view(-1)))
        loss = criterion(outputs, y.long())
        loss.backward()
        optimizer.step()

        running_loss += loss.item()
        if i%500 == 499:
            auc_score = roc_auc_score(all_y_true.cpu().numpy(), all_y_pred.cpu().numpy())
            print(f'[{epoch + 1}, {i + 1:5d}] loss: {running_loss / 500:.3f} auc_score_train: {auc_score}')
            running_loss = 0.0
    
    with torch.no_grad():   
        for j, data in enumerate(valset,0):
            X_val,y_val = data
            if torch.cuda.is_available():
                X_val = X_val.cuda()
                y_val = y_val.cuda()
            val_outputs = model(X_val)
            loss_val = criterion(val_outputs, y_val.long())
            _,val_preds = torch.max(val_outputs, 1)
            all_y_true_val=torch.cat((all_y_true_val,y_val.view(-1)))
            all_y_pred_val=torch.cat((all_y_pred_val,val_preds.view(-1)))
            val_loss += loss_val.item()
    auc_score_val = roc_auc_score(all_y_true_val.cpu().numpy(), all_y_pred_val.cpu().numpy())
    print(f'val_loss: {val_loss/j:.3f} auc_score_val: {auc_score_val}')
# Out:
# [1,   500] loss: 0.689 auc_score_train: 0.5446973756680915
# [1,  1000] loss: 0.677 auc_score_train: 0.5639866795837672
# [1,  1500] loss: 0.668 auc_score_train: 0.5753346533364443
# val_loss: 0.670 auc_score_val: 0.5964844172453844
# [2,   500] loss: 0.665 auc_score_train: 0.6036049964386778
# [2,  1000] loss: 0.663 auc_score_train: 0.6057784551359567
# [2,  1500] loss: 0.661 auc_score_train: 0.6075812348264504
# val_loss: 0.666 auc_score_val: 0.6106017600960504
# [3,   500] loss: 0.660 auc_score_train: 0.6112778021791709
# [3,  1000] loss: 0.660 auc_score_train: 0.6123604498275471
# [3,  1500] loss: 0.658 auc_score_train: 0.6136197520054314
# val_loss: 0.663 auc_score_val: 0.6149604132033533
# [4,   500] loss: 0.658 auc_score_train: 0.6158627827419874
# [4,  1000] loss: 0.658 auc_score_train: 0.615840777345405
# [4,  1500] loss: 0.656 auc_score_train: 0.6168807770981042
# val_loss: 0.661 auc_score_val: 0.6186998513441502
# [5,   500] loss: 0.656 auc_score_train: 0.6184601164085904
# [5,  1000] loss: 0.654 auc_score_train: 0.6199338480058207
# [5,  1500] loss: 0.654 auc_score_train: 0.6200992988837069
# val_loss: 0.660 auc_score_val: 0.6189187396428822
# [6,   500] loss: 0.652 auc_score_train: 0.6234257933175358
# [6,  1000] loss: 0.654 auc_score_train: 0.6222717868178562
# [6,  1500] loss: 0.652 auc_score_train: 0.6227050235946827
# val_loss: 0.658 auc_score_val: 0.6236152711481039
# [7,   500] loss: 0.653 auc_score_train: 0.6229354815653667
# [7,  1000] loss: 0.650 auc_score_train: 0.6252311265963139
# [7,  1500] loss: 0.650 auc_score_train: 0.6254754041640438
# val_loss: 0.658 auc_score_val: 0.6213995269208881
# [8,   500] loss: 0.649 auc_score_train: 0.6293652557757254
# [8,  1000] loss: 0.649 auc_score_train: 0.6291181803066639
# [8,  1500] loss: 0.650 auc_score_train: 0.6284020627765798
# val_loss: 0.655 auc_score_val: 0.6267273217570928
# [9,   500] loss: 0.647 auc_score_train: 0.6310001418703978
# [9,  1000] loss: 0.649 auc_score_train: 0.6297660356214729
# [9,  1500] loss: 0.647 auc_score_train: 0.6304075245308283
# val_loss: 0.653 auc_score_val: 0.6297743079721057
# [10,   500] loss: 0.645 auc_score_train: 0.6341195423391612
# [10,  1000] loss: 0.645 auc_score_train: 0.634469022405279
# [10,  1500] loss: 0.645 auc_score_train: 0.6345664011542623
# val_loss: 0.651 auc_score_val: 0.6331756112638522
# [11,   500] loss: 0.644 auc_score_train: 0.6359904363413591
# [11,  1000] loss: 0.643 auc_score_train: 0.6370682911365755
# [11,  1500] loss: 0.643 auc_score_train: 0.6370670766647868
# val_loss: 0.649 auc_score_val: 0.6344131234566521
# [12,   500] loss: 0.643 auc_score_train: 0.6386990592645625
# [12,  1000] loss: 0.641 auc_score_train: 0.6404220043451556
# [12,  1500] loss: 0.640 auc_score_train: 0.6413229166666666
# val_loss: 0.647 auc_score_val: 0.6388662231608326
# [13,   500] loss: 0.639 auc_score_train: 0.6435725326658266
# [13,  1000] loss: 0.638 auc_score_train: 0.6446671153319643
# [13,  1500] loss: 0.638 auc_score_train: 0.6450390894406999
# val_loss: 0.644 auc_score_val: 0.6411965074955892
# [14,   500] loss: 0.636 auc_score_train: 0.6485514479647024
# [14,  1000] loss: 0.635 auc_score_train: 0.6489223430457438
# [14,  1500] loss: 0.634 auc_score_train: 0.6497654240425208
# val_loss: 0.641 auc_score_val: 0.6458898793293233
# [15,   500] loss: 0.632 auc_score_train: 0.6540117940616499
# [15,  1000] loss: 0.632 auc_score_train: 0.6542883155005823
# [15,  1500] loss: 0.632 auc_score_train: 0.654441225144079
# val_loss: 0.638 auc_score_val: 0.6500958746587127
# [16,   500] loss: 0.630 auc_score_train: 0.6587053325856498
# [16,  1000] loss: 0.630 auc_score_train: 0.6584333225859855
# [16,  1500] loss: 0.628 auc_score_train: 0.6593392968459294
# val_loss: 0.636 auc_score_val: 0.654102357459445
# [17,   500] loss: 0.627 auc_score_train: 0.661660026247899
# [17,  1000] loss: 0.627 auc_score_train: 0.6626550368747174
# [17,  1500] loss: 0.624 auc_score_train: 0.6641393351370373
# val_loss: 0.632 auc_score_val: 0.65906338846809
# [18,   500] loss: 0.623 auc_score_train: 0.6678091265165655
# [18,  1000] loss: 0.622 auc_score_train: 0.6687191764931472
# [18,  1500] loss: 0.621 auc_score_train: 0.6697318663902593
# val_loss: 0.628 auc_score_val: 0.6655329101930525
# [19,   500] loss: 0.620 auc_score_train: 0.6727043323525348
# [19,  1000] loss: 0.617 auc_score_train: 0.6750982601967993
# [19,  1500] loss: 0.618 auc_score_train: 0.6750654665033131
# val_loss: 0.625 auc_score_val: 0.6694292819101869
# [20,   500] loss: 0.615 auc_score_train: 0.6786110742542095
# [20,  1000] loss: 0.615 auc_score_train: 0.6787100605400314
# [20,  1500] loss: 0.615 auc_score_train: 0.6787368297176529
# val_loss: 0.622 auc_score_val: 0.6741160553692122
# [21,   500] loss: 0.612 auc_score_train: 0.6839617276483404
# [21,  1000] loss: 0.612 auc_score_train: 0.6839315841911855
# [21,  1500] loss: 0.613 auc_score_train: 0.6834780515441408
# val_loss: 0.619 auc_score_val: 0.6765022766957256
# [22,   500] loss: 0.610 auc_score_train: 0.6855826592297304
# [22,  1000] loss: 0.609 auc_score_train: 0.6863347032523442
# [22,  1500] loss: 0.609 auc_score_train: 0.6866960987824775
# val_loss: 0.616 auc_score_val: 0.6801879633245334
# [23,   500] loss: 0.608 auc_score_train: 0.6891838282861433
# [23,  1000] loss: 0.607 auc_score_train: 0.6897323055165216
# [23,  1500] loss: 0.605 auc_score_train: 0.6900091550715522
# val_loss: 0.613 auc_score_val: 0.684521448737151
# [24,   500] loss: 0.605 auc_score_train: 0.692780006320666
# [24,  1000] loss: 0.605 auc_score_train: 0.6924268300795685
# [24,  1500] loss: 0.603 auc_score_train: 0.6931885782265074
# val_loss: 0.611 auc_score_val: 0.6880207728126135
# [25,   500] loss: 0.602 auc_score_train: 0.6951616459024558
# [25,  1000] loss: 0.602 auc_score_train: 0.6956041721518554
# [25,  1500] loss: 0.602 auc_score_train: 0.6955247718712019
# val_loss: 0.609 auc_score_val: 0.6893455896802155
# [26,   500] loss: 0.599 auc_score_train: 0.6994779596668217
# [26,  1000] loss: 0.601 auc_score_train: 0.6974667038562861
# [26,  1500] loss: 0.601 auc_score_train: 0.6970032470822236
# val_loss: 0.607 auc_score_val: 0.6931148551843688
# [27,   500] loss: 0.599 auc_score_train: 0.698673159963974
# [27,  1000] loss: 0.599 auc_score_train: 0.6984878494814256
# [27,  1500] loss: 0.598 auc_score_train: 0.6988813254393113
# val_loss: 0.606 auc_score_val: 0.6931610405815303
# [28,   500] loss: 0.597 auc_score_train: 0.7006278894196262
# [28,  1000] loss: 0.596 auc_score_train: 0.7010960438082074
# [28,  1500] loss: 0.596 auc_score_train: 0.7012828216140031
# val_loss: 0.604 auc_score_val: 0.6961115221390133
# [29,   500] loss: 0.597 auc_score_train: 0.701902407210865
# [29,  1000] loss: 0.595 auc_score_train: 0.7024795774178182
# [29,  1500] loss: 0.595 auc_score_train: 0.7025461030295195
# val_loss: 0.602 auc_score_val: 0.6963797313128915
# [30,   500] loss: 0.595 auc_score_train: 0.7024870110230346
# [30,  1000] loss: 0.595 auc_score_train: 0.7027107725831525
# [30,  1500] loss: 0.594 auc_score_train: 0.7033417403973408
# val_loss: 0.603 auc_score_val: 0.6978886623509629
# [31,   500] loss: 0.594 auc_score_train: 0.7031928258857524
# [31,  1000] loss: 0.595 auc_score_train: 0.703202189873563
# [31,  1500] loss: 0.592 auc_score_train: 0.7042549249348012
# val_loss: 0.600 auc_score_val: 0.6992046695576849
# [32,   500] loss: 0.592 auc_score_train: 0.7071344580301695
# [32,  1000] loss: 0.593 auc_score_train: 0.7061960944293347
# [32,  1500] loss: 0.592 auc_score_train: 0.7064107862224006
# val_loss: 0.600 auc_score_val: 0.7000667518101628
# [33,   500] loss: 0.592 auc_score_train: 0.7064706461937942
# [33,  1000] loss: 0.591 auc_score_train: 0.7065383062820034
# [33,  1500] loss: 0.590 auc_score_train: 0.707527460774106
# val_loss: 0.599 auc_score_val: 0.7006848651658338
# [34,   500] loss: 0.590 auc_score_train: 0.70968660369966
# [34,  1000] loss: 0.590 auc_score_train: 0.7090397255373356
# [34,  1500] loss: 0.591 auc_score_train: 0.7085494982459817
# val_loss: 0.598 auc_score_val: 0.7026309728024962
# [35,   500] loss: 0.590 auc_score_train: 0.7077934582016788
# [35,  1000] loss: 0.590 auc_score_train: 0.7086525294028738
# [35,  1500] loss: 0.588 auc_score_train: 0.709394445173458
# val_loss: 0.597 auc_score_val: 0.7023690507135887
# [36,   500] loss: 0.587 auc_score_train: 0.713015220997956
# [36,  1000] loss: 0.590 auc_score_train: 0.7106268547370527
# [36,  1500] loss: 0.590 auc_score_train: 0.710086405494501
# val_loss: 0.597 auc_score_val: 0.7035769678006605
# [37,   500] loss: 0.590 auc_score_train: 0.7088941932424456
# [37,  1000] loss: 0.587 auc_score_train: 0.7104243369555017
# [37,  1500] loss: 0.588 auc_score_train: 0.7108532982336515
# val_loss: 0.596 auc_score_val: 0.7051452180822035
# [38,   500] loss: 0.587 auc_score_train: 0.7115395586453954
# [38,  1000] loss: 0.587 auc_score_train: 0.7119484434811134
# [38,  1500] loss: 0.588 auc_score_train: 0.7118964820832557
# val_loss: 0.596 auc_score_val: 0.7049647522919812
# [39,   500] loss: 0.587 auc_score_train: 0.7119726991461041
# [39,  1000] loss: 0.587 auc_score_train: 0.7122263228145669
# [39,  1500] loss: 0.587 auc_score_train: 0.7123553667336003
# val_loss: 0.595 auc_score_val: 0.7048616234533391
# [40,   500] loss: 0.586 auc_score_train: 0.7135065544851986
# [40,  1000] loss: 0.587 auc_score_train: 0.7130538366986748
# [40,  1500] loss: 0.585 auc_score_train: 0.713803096527494
# val_loss: 0.595 auc_score_val: 0.7049192120548986
# [41,   500] loss: 0.585 auc_score_train: 0.7136858492244074
# [41,  1000] loss: 0.586 auc_score_train: 0.7139788456239768
# [41,  1500] loss: 0.585 auc_score_train: 0.7145510111579044
# val_loss: 0.594 auc_score_val: 0.7075229087795712
# [42,   500] loss: 0.586 auc_score_train: 0.7130484163240304
# [42,  1000] loss: 0.583 auc_score_train: 0.7147282835031536
# [42,  1500] loss: 0.585 auc_score_train: 0.7145458073570239
# val_loss: 0.593 auc_score_val: 0.7076908310449559
# [43,   500] loss: 0.584 auc_score_train: 0.7156380388452861
# [43,  1000] loss: 0.583 auc_score_train: 0.7163939944986314
# [43,  1500] loss: 0.586 auc_score_train: 0.7157840796235005
# val_loss: 0.593 auc_score_val: 0.7079628708568038
# [44,   500] loss: 0.584 auc_score_train: 0.715601667233132
# [44,  1000] loss: 0.584 auc_score_train: 0.7159641435648277
# [44,  1500] loss: 0.585 auc_score_train: 0.7155195817815064
# val_loss: 0.592 auc_score_val: 0.7090097753429379
# [45,   500] loss: 0.583 auc_score_train: 0.7163268605664564
# [45,  1000] loss: 0.582 auc_score_train: 0.7172045955702746
# [45,  1500] loss: 0.584 auc_score_train: 0.7166316173227735
# val_loss: 0.592 auc_score_val: 0.708206239754737
# [46,   500] loss: 0.582 auc_score_train: 0.7188151018920783
# [46,  1000] loss: 0.584 auc_score_train: 0.7175084040946713
# [46,  1500] loss: 0.582 auc_score_train: 0.7176463243071987
# val_loss: 0.592 auc_score_val: 0.7087600145215212
# [47,   500] loss: 0.583 auc_score_train: 0.7171377474184558
# [47,  1000] loss: 0.582 auc_score_train: 0.7174032621095634
# [47,  1500] loss: 0.581 auc_score_train: 0.7181506004496682
# val_loss: 0.592 auc_score_val: 0.7082617380376403
# [48,   500] loss: 0.581 auc_score_train: 0.7208686622679029
# [48,  1000] loss: 0.582 auc_score_train: 0.7195983789650837
# [48,  1500] loss: 0.583 auc_score_train: 0.7187461289297233
# val_loss: 0.591 auc_score_val: 0.7088961303950068
# [49,   500] loss: 0.582 auc_score_train: 0.7187134735594306
# [49,  1000] loss: 0.581 auc_score_train: 0.719314785699178
# [49,  1500] loss: 0.582 auc_score_train: 0.7191169895594686
# val_loss: 0.591 auc_score_val: 0.7092847119235408
# [50,   500] loss: 0.581 auc_score_train: 0.7196360205787397
# [50,  1000] loss: 0.580 auc_score_train: 0.7201915034712159
# [50,  1500] loss: 0.581 auc_score_train: 0.719876107187355
# val_loss: 0.590 auc_score_val: 0.7103449502556095
# [51,   500] loss: 0.582 auc_score_train: 0.7190049495844253
# [51,  1000] loss: 0.579 auc_score_train: 0.7204383283342838
# [51,  1500] loss: 0.579 auc_score_train: 0.7210422379429843
# val_loss: 0.591 auc_score_val: 0.7097667981152371
# [52,   500] loss: 0.579 auc_score_train: 0.7221411165750662
# [52,  1000] loss: 0.578 auc_score_train: 0.7226496058582503
# [52,  1500] loss: 0.582 auc_score_train: 0.7212109903476678
# val_loss: 0.590 auc_score_val: 0.7111631600098093
# [53,   500] loss: 0.580 auc_score_train: 0.7210981029438132
# [53,  1000] loss: 0.579 auc_score_train: 0.7216867695489185
# [53,  1500] loss: 0.578 auc_score_train: 0.7221176736031691
# val_loss: 0.590 auc_score_val: 0.7110269247817089
# [54,   500] loss: 0.578 auc_score_train: 0.7234742509329853
# [54,  1000] loss: 0.581 auc_score_train: 0.7221917640150464
# [54,  1500] loss: 0.579 auc_score_train: 0.7221341994826473
# val_loss: 0.590 auc_score_val: 0.7115044867883505
# [55,   500] loss: 0.579 auc_score_train: 0.722038825367664
# [55,  1000] loss: 0.579 auc_score_train: 0.7223245091105536
# [55,  1500] loss: 0.578 auc_score_train: 0.7223496695435525
# val_loss: 0.590 auc_score_val: 0.710886157304053
# [56,   500] loss: 0.579 auc_score_train: 0.7238621532091947
# [56,  1000] loss: 0.578 auc_score_train: 0.7240010183536101
# [56,  1500] loss: 0.576 auc_score_train: 0.724623332312177
# val_loss: 0.589 auc_score_val: 0.7114458368984611
# [57,   500] loss: 0.577 auc_score_train: 0.725023727564612
# [57,  1000] loss: 0.579 auc_score_train: 0.7239271215018289
# [57,  1500] loss: 0.577 auc_score_train: 0.7240792129861092
# val_loss: 0.589 auc_score_val: 0.7128973615926952
# [58,   500] loss: 0.578 auc_score_train: 0.7243830892721724
# [58,  1000] loss: 0.578 auc_score_train: 0.7241804199971379
# [58,  1500] loss: 0.576 auc_score_train: 0.7246514036645126
# val_loss: 0.589 auc_score_val: 0.7113335483995963
# [59,   500] loss: 0.576 auc_score_train: 0.7253297383167383
# [59,  1000] loss: 0.578 auc_score_train: 0.7250424203232594
# [59,  1500] loss: 0.576 auc_score_train: 0.7253054423565876
# val_loss: 0.590 auc_score_val: 0.7105471611662975
# [60,   500] loss: 0.576 auc_score_train: 0.7262694035857424
# [60,  1000] loss: 0.577 auc_score_train: 0.7253728867825108
# [60,  1500] loss: 0.576 auc_score_train: 0.7258590965301256
# val_loss: 0.589 auc_score_val: 0.7117907701218444
# [61,   500] loss: 0.575 auc_score_train: 0.7271612181178214
# [61,  1000] loss: 0.575 auc_score_train: 0.7269023197768176
# [61,  1500] loss: 0.577 auc_score_train: 0.7263307202730563
# val_loss: 0.589 auc_score_val: 0.7117036251241619
# [62,   500] loss: 0.575 auc_score_train: 0.7272065698544168
# [62,  1000] loss: 0.576 auc_score_train: 0.7267784535961982
# [62,  1500] loss: 0.577 auc_score_train: 0.7262329933734196
# val_loss: 0.589 auc_score_val: 0.7140318739788689
# [63,   500] loss: 0.575 auc_score_train: 0.7276423311493976
# [63,  1000] loss: 0.576 auc_score_train: 0.72693738641791
# [63,  1500] loss: 0.575 auc_score_train: 0.7268542759939253
# val_loss: 0.589 auc_score_val: 0.7135095072176348
# [64,   500] loss: 0.575 auc_score_train: 0.7265271342750814
# [64,  1000] loss: 0.575 auc_score_train: 0.7266032455672069
# [64,  1500] loss: 0.575 auc_score_train: 0.7267732236467387
# val_loss: 0.589 auc_score_val: 0.7140552142576301
# [65,   500] loss: 0.574 auc_score_train: 0.7283703528426173
# [65,  1000] loss: 0.575 auc_score_train: 0.7280454176851905
# [65,  1500] loss: 0.576 auc_score_train: 0.7273652330756494
# val_loss: 0.588 auc_score_val: 0.712174045208728
# [66,   500] loss: 0.572 auc_score_train: 0.7305729402809148
# [66,  1000] loss: 0.575 auc_score_train: 0.7291852051374801
# [66,  1500] loss: 0.575 auc_score_train: 0.728570136309342
# val_loss: 0.588 auc_score_val: 0.7121006888948357
# [67,   500] loss: 0.572 auc_score_train: 0.7308928374019659
# [67,  1000] loss: 0.575 auc_score_train: 0.729517747816301
# [67,  1500] loss: 0.574 auc_score_train: 0.7290591703881935
# val_loss: 0.588 auc_score_val: 0.7142631380608182
# [68,   500] loss: 0.573 auc_score_train: 0.7301854240256178
# [68,  1000] loss: 0.574 auc_score_train: 0.7303807508852712
# [68,  1500] loss: 0.574 auc_score_train: 0.7297437976013154
# val_loss: 0.588 auc_score_val: 0.7133859913204937
# [69,   500] loss: 0.573 auc_score_train: 0.7304507599564948
# [69,  1000] loss: 0.576 auc_score_train: 0.7287730314066099
# [69,  1500] loss: 0.572 auc_score_train: 0.7294554909536931
# val_loss: 0.588 auc_score_val: 0.7137591083619319
# [70,   500] loss: 0.572 auc_score_train: 0.7306737573878059
# [70,  1000] loss: 0.573 auc_score_train: 0.7302675343479662
# [70,  1500] loss: 0.574 auc_score_train: 0.7296069369304188
# val_loss: 0.588 auc_score_val: 0.7150012092557942
# [71,   500] loss: 0.572 auc_score_train: 0.7310971830601722
# [71,  1000] loss: 0.573 auc_score_train: 0.7303437441281748
# [71,  1500] loss: 0.573 auc_score_train: 0.7301824747865963
# val_loss: 0.588 auc_score_val: 0.7131839239579234
# [72,   500] loss: 0.571 auc_score_train: 0.7322189472072276
# [72,  1000] loss: 0.572 auc_score_train: 0.7317926667254434
# [72,  1500] loss: 0.573 auc_score_train: 0.7309093943186401
# val_loss: 0.589 auc_score_val: 0.7118900521935149
# [73,   500] loss: 0.572 auc_score_train: 0.7322423171001217
# [73,  1000] loss: 0.572 auc_score_train: 0.7318472442563547
# [73,  1500] loss: 0.573 auc_score_train: 0.7310665390897371
# val_loss: 0.588 auc_score_val: 0.7151359364222096
# [74,   500] loss: 0.570 auc_score_train: 0.7328981420659381
# [74,  1000] loss: 0.571 auc_score_train: 0.7333846179253044
# [74,  1500] loss: 0.573 auc_score_train: 0.7324088168441096
# val_loss: 0.588 auc_score_val: 0.7133732236025285
# [75,   500] loss: 0.570 auc_score_train: 0.733761126103247
# [75,  1000] loss: 0.571 auc_score_train: 0.7329304917314071
# [75,  1500] loss: 0.572 auc_score_train: 0.7325151764384785
# val_loss: 0.589 auc_score_val: 0.7119834133085595
# [76,   500] loss: 0.570 auc_score_train: 0.7332490601790417
# [76,  1000] loss: 0.571 auc_score_train: 0.7331505138313389
# [76,  1500] loss: 0.571 auc_score_train: 0.7328094293105502
# val_loss: 0.589 auc_score_val: 0.7111718664450767
# [77,   500] loss: 0.570 auc_score_train: 0.7345751505832041
# [77,  1000] loss: 0.571 auc_score_train: 0.7332553723757101
# [77,  1500] loss: 0.570 auc_score_train: 0.7333770619619782
# val_loss: 0.588 auc_score_val: 0.7133290091694086
# [78,   500] loss: 0.569 auc_score_train: 0.7354658793101475
# [78,  1000] loss: 0.569 auc_score_train: 0.7354711163662339
# [78,  1500] loss: 0.571 auc_score_train: 0.7344475197379999
# val_loss: 0.588 auc_score_val: 0.7142592122617369
# [79,   500] loss: 0.570 auc_score_train: 0.7346742217994393
# [79,  1000] loss: 0.569 auc_score_train: 0.7350002005332432
# [79,  1500] loss: 0.570 auc_score_train: 0.7343923189002282
# val_loss: 0.588 auc_score_val: 0.713738648722924
# [80,   500] loss: 0.568 auc_score_train: 0.7360948241707479
# [80,  1000] loss: 0.569 auc_score_train: 0.7355935546099192
# [80,  1500] loss: 0.571 auc_score_train: 0.7349708882510092
# val_loss: 0.588 auc_score_val: 0.7131319934102575
# [81,   500] loss: 0.568 auc_score_train: 0.7367563175513435
# [81,  1000] loss: 0.568 auc_score_train: 0.7364560512576206
# [81,  1500] loss: 0.570 auc_score_train: 0.735512300858964
# val_loss: 0.588 auc_score_val: 0.7141726656500277
# [82,   500] loss: 0.567 auc_score_train: 0.7375683178225325
# [82,  1000] loss: 0.569 auc_score_train: 0.7359612892111826
# [82,  1500] loss: 0.571 auc_score_train: 0.7347353299972564
# val_loss: 0.588 auc_score_val: 0.7137659148007663
# [83,   500] loss: 0.569 auc_score_train: 0.7356360700764217
# [83,  1000] loss: 0.569 auc_score_train: 0.7352114398814602
# [83,  1500] loss: 0.568 auc_score_train: 0.7354760524663433
# val_loss: 0.588 auc_score_val: 0.7137660825423869
# [84,   500] loss: 0.566 auc_score_train: 0.7376940398922599
# [84,  1000] loss: 0.568 auc_score_train: 0.7375997493799359
# [84,  1500] loss: 0.567 auc_score_train: 0.7374799141019169
# val_loss: 0.588 auc_score_val: 0.7138142711615941
# [85,   500] loss: 0.566 auc_score_train: 0.7384231654985922
# [85,  1000] loss: 0.567 auc_score_train: 0.7383325187860257
# [85,  1500] loss: 0.568 auc_score_train: 0.7376082353872305
# val_loss: 0.588 auc_score_val: 0.7136195215272209
# [86,   500] loss: 0.567 auc_score_train: 0.7373974363992296
# [86,  1000] loss: 0.568 auc_score_train: 0.7370179255438284
# [86,  1500] loss: 0.567 auc_score_train: 0.7372262895662265
# val_loss: 0.588 auc_score_val: 0.713190651364648
# [87,   500] loss: 0.567 auc_score_train: 0.7383221717111496
# [87,  1000] loss: 0.566 auc_score_train: 0.7385917480023116
# [87,  1500] loss: 0.567 auc_score_train: 0.7383194706305625
# val_loss: 0.588 auc_score_val: 0.7134896298355982
# [88,   500] loss: 0.567 auc_score_train: 0.7374198548825408
# [88,  1000] loss: 0.565 auc_score_train: 0.7388539577892831
# [88,  1500] loss: 0.566 auc_score_train: 0.7386705239207163
# val_loss: 0.588 auc_score_val: 0.712664605578063
# [89,   500] loss: 0.566 auc_score_train: 0.7394403966005196
# [89,  1000] loss: 0.566 auc_score_train: 0.7390358444980897
# [89,  1500] loss: 0.567 auc_score_train: 0.7387656640113955
# val_loss: 0.588 auc_score_val: 0.7127650763571793
# [90,   500] loss: 0.564 auc_score_train: 0.7411488996567461
# [90,  1000] loss: 0.565 auc_score_train: 0.7406774785153123
# [90,  1500] loss: 0.567 auc_score_train: 0.7397162095552143
# val_loss: 0.588 auc_score_val: 0.7132810834529337
# [91,   500] loss: 0.565 auc_score_train: 0.7407732572499832
# [91,  1000] loss: 0.565 auc_score_train: 0.7404841295007619
# [91,  1500] loss: 0.566 auc_score_train: 0.7400305290380442
# val_loss: 0.589 auc_score_val: 0.7120009439208085
# [92,   500] loss: 0.564 auc_score_train: 0.7414166171170437
# [92,  1000] loss: 0.567 auc_score_train: 0.740042986789823
# [92,  1500] loss: 0.565 auc_score_train: 0.739987657329838
# val_loss: 0.589 auc_score_val: 0.7116922703067698
# [93,   500] loss: 0.565 auc_score_train: 0.7404730232709507
# [93,  1000] loss: 0.564 auc_score_train: 0.7414094079214231
# [93,  1500] loss: 0.565 auc_score_train: 0.7414825734663795
# val_loss: 0.588 auc_score_val: 0.7126629055812547
# [94,   500] loss: 0.564 auc_score_train: 0.7422997496881814
# [94,  1000] loss: 0.563 auc_score_train: 0.7427462857150356
# [94,  1500] loss: 0.565 auc_score_train: 0.7419519569790152
# val_loss: 0.589 auc_score_val: 0.7115866205051189
# [95,   500] loss: 0.565 auc_score_train: 0.74038800075811
# [95,  1000] loss: 0.565 auc_score_train: 0.740798755877935
# [95,  1500] loss: 0.563 auc_score_train: 0.7414105048493659
# val_loss: 0.589 auc_score_val: 0.7111916470531012
# [96,   500] loss: 0.562 auc_score_train: 0.7453897858892542
# [96,  1000] loss: 0.565 auc_score_train: 0.7427487855245513
# [96,  1500] loss: 0.566 auc_score_train: 0.7420649182840817
# val_loss: 0.588 auc_score_val: 0.7120091310022121
# [97,   500] loss: 0.563 auc_score_train: 0.7423478806069902
# [97,  1000] loss: 0.565 auc_score_train: 0.7416039405299397
# [97,  1500] loss: 0.563 auc_score_train: 0.7420272643488475
# val_loss: 0.589 auc_score_val: 0.7119588036773428
# [98,   500] loss: 0.563 auc_score_train: 0.7430162047433381
# [98,  1000] loss: 0.563 auc_score_train: 0.7429199195086928
# [98,  1500] loss: 0.563 auc_score_train: 0.7429266529627345
# val_loss: 0.589 auc_score_val: 0.7120938501979974
# [99,   500] loss: 0.562 auc_score_train: 0.7444047207807784
# [99,  1000] loss: 0.563 auc_score_train: 0.7441809624277484
# [99,  1500] loss: 0.564 auc_score_train: 0.7434351256164149
# val_loss: 0.590 auc_score_val: 0.7092738119440047
# [100,   500] loss: 0.562 auc_score_train: 0.744262987411153
# [100,  1000] loss: 0.562 auc_score_train: 0.7443288293999298
# [100,  1500] loss: 0.563 auc_score_train: 0.7438840452367779
# val_loss: 0.590 auc_score_val: 0.7096779934432511

# %% [markdown]
# As seen from the epoch metrics, we got:
#
# Train AUC Score: 0.74
#
# Validation AUC Score: 0.71
